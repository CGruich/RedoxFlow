# %%
import os
from helpers import prepare_scripts

# %%
# Local Code Repo Location
os.environ["REDOXGIT"] = "/home/cameron/Documents/Github/RedoxFlow"

# %%
agent_raw_output = prepare_scripts(num_generated_reactants=10, # Number of generated reactants
                    max_heavy_atoms_per_reactant=16, # Max # of non-hydrogen atoms per reactant
                    min_uniq_elements=1, # Min of non-C elements allowed in the molecule
                    temperature=0.425, # Higher -> More unusual structures, more electronegatives
                    device='auto', # 'cpu', 'cuda:0' for GPUs, 'auto' to auto-determine
                    verbose=True) # Print out script preparation progress)
# Out:
# ________________________________________________________________________________________________
# [REDUCTION CANDIDATE SEARCH]
#  rc=0  cmd: /home/cameron/Documents/envs/chemflow/bin/python /home/cameron/Documents/Github/RedoxFlow/scripts/reduce.py --molecules /home/cameron/Documents/Github/RedoxFlow/memory/reactants_memory.csv --reactions /home/cameron/Documents/Github/RedoxFlow/scripts/reactions.json --out /home/cameron/Documents/Github/RedoxFlow/memory/reduction_candidates.csv --depth 2
#
# --- Output ---
# Wrote 40 rows to /home/cameron/Documents/Github/RedoxFlow/memory/reduction_candidates.csv
#
#
#
#
# ________________________________________________________________________________________________
# [CONFORMER SEARCH]
#  rc=0  cmd: /home/cameron/Documents/envs/chemflow/bin/python /home/cameron/Documents/Github/RedoxFlow/scripts/conformer.py --in /home/cameron/Documents/Github/RedoxFlow/memory/reduction_candidates.csv --out /home/cameron/Documents/Github/RedoxFlow/memory/products_memory.csv --max-confs 200 --min-steps 1000 --seed 1337 --batch-size 1000
#
# --- Output ---
# [prune] skipped (no memory): /home/cameron/Documents/Github/memory/products_memory.csv not initialized
#
#
#
# [row 0] Product_SMILES='CC(C)C(O)N1CCCCC1C(N)=O' -> E=3.374460 kcal/mol
# [row 1] Product_SMILES='CC(C)C(=O)N1CCCCC1C(N)O' -> E=11.647250 kcal/mol
# [row 2] Product_SMILES='CC(C)CN1CCCCC1C(N)=O' -> E=1.374780 kcal/mol
# [row 3] Product_SMILES='CC(C)C(=O)N1CCCCC1CN' -> E=-9.692170 kcal/mol
# [row 4] Product_SMILES='CC(C)C(O)N1CCCCC1C(N)O' -> E=-0.202250 kcal/mol
# [row 5] Product_SMILES='CC(C)C(O)N1CCCCC1CN' -> E=21.875150 kcal/mol
# [row 6] Product_SMILES='CC(C)CN1CCCCC1C(N)O' -> E=-41.709770 kcal/mol
# [row 7] Product_SMILES='CC(C)CN1CCCCC1CN' -> E=-13.332560 kcal/mol
# [row 8] Product_SMILES='CCCC1CCCN1COC(C)(C)C' -> E=4.648020 kcal/mol
# [row 9] Product_SMILES='C1CCCCC1' -> E=17.140610 kcal/mol
# [row 10] Product_SMILES='OCc1ccccc1' -> E=0.732700 kcal/mol
# [row 11] Product_SMILES='CCC(C)C(C)NCc1ccccc1' -> E=-4.685410 kcal/mol
# [row 13] Product_SMILES='CC(C)C(O)N1CC2CCC(C1)N2' -> E=-0.004540 kcal/mol
# [row 14] Product_SMILES='CC(C)CN1CC2CCC(C1)N2' -> E=23.377730 kcal/mol
# [row 15] Product_SMILES='CNc1cc(NC(O)C2CC2)ccc1C' -> E=-52.749000 kcal/mol
# [row 17] Product_SMILES='CNc1cc(NCC2CC2)ccc1C' -> E=-11.539890 kcal/mol
# [row 18] Product_SMILES='COc1cc(C)ccc1NC(=O)CO' -> E=3.464680 kcal/mol
# [row 19] Product_SMILES='COc1cc(C)ccc1NC(O)C=O' -> E=5.462050 kcal/mol
# [row 21] Product_SMILES='COc1cc(C)ccc1NCC=O' -> E=1.247880 kcal/mol
# [row 22] Product_SMILES='[CH2]C(=O)Nc1ccc(C)cc1OC' -> E=-12.452990 kcal/mol
# [row 23] Product_SMILES='COc1cc(C)ccc1NC(C)=O' -> E=-0.629390 kcal/mol
# [row 24] Product_SMILES='COc1cc(C)ccc1NC(O)CO' -> E=21.177140 kcal/mol
# [row 25] Product_SMILES='COc1cc(C)ccc1NCCO' -> E=-0.816730 kcal/mol
# [row 26] Product_SMILES='[CH2]C(O)Nc1ccc(C)cc1OC' -> E=17.452630 kcal/mol
# [row 27] Product_SMILES='COc1cc(C)ccc1NC(C)O' -> E=4.056780 kcal/mol
# [row 28] Product_SMILES='[CH2]CNc1ccc(C)cc1OC' -> E=7.512820 kcal/mol
# [row 29] Product_SMILES='CCNc1ccc(C)cc1OC' -> E=0.528940 kcal/mol
# [row 30] Product_SMILES='CC(C)CC(N)CNC(O)C1CCCC1' -> E=-7.659360 kcal/mol
# [row 31] Product_SMILES='CC(C)CC(N)CNCC1CCCC1' -> E=-0.358450 kcal/mol
# [row 32] Product_SMILES='CC(O)N1CCCCC1C(=O)NCCCN' -> E=23.488520 kcal/mol
# [row 33] Product_SMILES='CC(=O)N1CCCCC1C(O)NCCCN' -> E=-7.000830 kcal/mol
# [row 34] Product_SMILES='CCN1CCCCC1C(=O)NCCCN' -> E=20.568420 kcal/mol
# [row 35] Product_SMILES='CC(=O)N1CCCCC1CNCCCN' -> E=5.261320 kcal/mol
# [row 36] Product_SMILES='CC(O)N1CCCCC1C(O)NCCCN' -> E=13.382630 kcal/mol
# [row 37] Product_SMILES='CC(O)N1CCCCC1CNCCCN' -> E=1.567180 kcal/mol
# [row 38] Product_SMILES='CCN1CCCCC1C(O)NCCCN' -> E=-18.536460 kcal/mol
# [row 39] Product_SMILES='CCN1CCCCC1CNCCCN' -> E=0.000000 kcal/mol
# Wrote 9 winners to /home/cameron/Documents/Github/RedoxFlow/memory/products_memory.csv
# [diag] reactant '1' SMILES='CC(C)C(=O)N1CCCCC1C(N)=O' -> E=4.978710 kcal/mol
# [diag] reactant '2' SMILES='CCCC1CCCN1C(=O)OC(C)(C)C' -> E=13.447370 kcal/mol
# [diag] reactant '3' SMILES='CCC(C)C(C)NC(=O)c1ccccc1' -> E=0.792760 kcal/mol
# [diag] reactant '4' SMILES='Cc1nc(-c2ccccc2)oc1C(C)N' -> E=8.988730 kcal/mol
# [diag] reactant '5' SMILES='CC(C)C(=O)N1CC2CCC(C1)N2' -> E=-2.352350 kcal/mol
# [diag] reactant '6' SMILES='CNc1cc(NC(=O)C2CC2)ccc1C' -> E=26.063650 kcal/mol
# [diag] reactant '7' SMILES='COc1cc(C)ccc1NC(=O)C=O' -> E=-42.808820 kcal/mol
# [diag] reactant '9' SMILES='CC(C)CC(N)CNC(=O)C1CCCC1' -> E=9.110040 kcal/mol
# [diag] reactant '10' SMILES='CC(=O)N1CCCCC1C(=O)NCCCN' -> E=2.334000 kcal/mol
#
# ________________________________________________________________________________________________
# [SCRIPT GENERATION]
#  rc=0  cmd: /home/cameron/Documents/envs/chemflow/bin/python /home/cameron/Documents/Github/RedoxFlow/scripts/generate_nw.py --reactants_in /home/cameron/Documents/Github/RedoxFlow/memory/reactants --products_in /home/cameron/Documents/Github/RedoxFlow/memory/products --scripts_out /home/cameron/Documents/Github/RedoxFlow/memory/scripts
#
# --- Output ---
# [info] found 18 XYZ files in /home/cameron/Documents/Github/RedoxFlow/memory/reactants, /home/cameron/Documents/Github/RedoxFlow/memory/products
# [do ] reactant  react_1.xyz                SMILES=CC(C)C(=O)N1CCCCC1C(N)=O
# [ok] wrote /home/cameron/Documents/Github/RedoxFlow/memory/scripts/reactants/react_1/react_1.nw  (geom=react_1.xyz, charge=0, mult=1)
# [do ] reactant  react_10.xyz               SMILES=CC(=O)N1CCCCC1C(=O)NCCCN
# [ok] wrote /home/cameron/Documents/Github/RedoxFlow/memory/scripts/reactants/react_10/react_10.nw  (geom=react_10.xyz, charge=0, mult=1)
# [do ] reactant  react_2.xyz                SMILES=CCCC1CCCN1C(=O)OC(C)(C)C
# [ok] wrote /home/cameron/Documents/Github/RedoxFlow/memory/scripts/reactants/react_2/react_2.nw  (geom=react_2.xyz, charge=0, mult=1)
# [do ] reactant  react_3.xyz                SMILES=CCC(C)C(C)NC(=O)c1ccccc1
# [ok] wrote /home/cameron/Documents/Github/RedoxFlow/memory/scripts/reactants/react_3/react_3.nw  (geom=react_3.xyz, charge=0, mult=1)
# [do ] reactant  react_4.xyz                SMILES=Cc1nc(-c2ccccc2)oc1C(C)N
# [ok] wrote /home/cameron/Documents/Github/RedoxFlow/memory/scripts/reactants/react_4/react_4.nw  (geom=react_4.xyz, charge=0, mult=1)
# [do ] reactant  react_5.xyz                SMILES=CC(C)C(=O)N1CC2CCC(C1)N2
# [ok] wrote /home/cameron/Documents/Github/RedoxFlow/memory/scripts/reactants/react_5/react_5.nw  (geom=react_5.xyz, charge=0, mult=1)
# [do ] reactant  react_6.xyz                SMILES=CNc1cc(NC(=O)C2CC2)ccc1C
# [ok] wrote /home/cameron/Documents/Github/RedoxFlow/memory/scripts/reactants/react_6/react_6.nw  (geom=react_6.xyz, charge=0, mult=1)
# [do ] reactant  react_7.xyz                SMILES=COc1cc(C)ccc1NC(=O)C=O
# [ok] wrote /home/cameron/Documents/Github/RedoxFlow/memory/scripts/reactants/react_7/react_7.nw  (geom=react_7.xyz, charge=0, mult=1)
# [do ] reactant  react_9.xyz                SMILES=CC(C)CC(N)CNC(=O)C1CCCC1
# [ok] wrote /home/cameron/Documents/Github/RedoxFlow/memory/scripts/reactants/react_9/react_9.nw  (geom=react_9.xyz, charge=0, mult=1)
# [do ] product   prod_1.xyz                 SMILES=CC(C)CN1CCCCC1C(N)O
# [ok] wrote /home/cameron/Documents/Github/RedoxFlow/memory/scripts/products/prod_1/prod_1.nw  (geom=prod_1.xyz, charge=0, mult=1)
# [do ] product   prod_10.xyz                SMILES=CCN1CCCCC1C(O)NCCCN
# [ok] wrote /home/cameron/Documents/Github/RedoxFlow/memory/scripts/products/prod_10/prod_10.nw  (geom=prod_10.xyz, charge=0, mult=1)
# [do ] product   prod_2.xyz                 SMILES=CCCC1CCCN1COC(C)(C)C
# [ok] wrote /home/cameron/Documents/Github/RedoxFlow/memory/scripts/products/prod_2/prod_2.nw  (geom=prod_2.xyz, charge=0, mult=1)
# [do ] product   prod_3.xyz                 SMILES=CCC(C)C(C)NCc1ccccc1
# [ok] wrote /home/cameron/Documents/Github/RedoxFlow/memory/scripts/products/prod_3/prod_3.nw  (geom=prod_3.xyz, charge=0, mult=1)
# [do ] product   prod_4.xyz                 SMILES=C1CCCCC1
# [ok] wrote /home/cameron/Documents/Github/RedoxFlow/memory/scripts/products/prod_4/prod_4.nw  (geom=prod_4.xyz, charge=0, mult=1)
# [do ] product   prod_5.xyz                 SMILES=CC(C)C(O)N1CC2CCC(C1)N2
# [ok] wrote /home/cameron/Documents/Github/RedoxFlow/memory/scripts/products/prod_5/prod_5.nw  (geom=prod_5.xyz, charge=0, mult=1)
# [do ] product   prod_6.xyz                 SMILES=CNc1cc(NC(O)C2CC2)ccc1C
# [ok] wrote /home/cameron/Documents/Github/RedoxFlow/memory/scripts/products/prod_6/prod_6.nw  (geom=prod_6.xyz, charge=0, mult=1)
# [do ] product   prod_7.xyz                 SMILES=[CH2]C(=O)Nc1ccc(C)cc1OC
# [ok] wrote /home/cameron/Documents/Github/RedoxFlow/memory/scripts/products/prod_7/prod_7.nw  (geom=prod_7.xyz, charge=0, mult=2)
# [do ] product   prod_9.xyz                 SMILES=CC(C)CC(N)CNC(O)C1CCCC1
# [ok] wrote /home/cameron/Documents/Github/RedoxFlow/memory/scripts/products/prod_9/prod_9.nw  (geom=prod_9.xyz, charge=0, mult=1)
# [done] 18 ok, 0 failed
#
#
#
#
# ________________________________________________________________________________________________
