# %%
import os
from helpers import prepare_scripts

# %%
# Local Code Repo Location
os.environ["REDOXGIT"] = "/home/cameron/Documents/Github/RedoxFlow"

# %%
agent_raw_output = prepare_scripts(num_generated_reactants=10, # Number of generated reactants
                    max_heavy_atoms_per_reactant=16, # Max # of non-hydrogen atoms per reactant
                    min_uniq_elements=1, # Max # of non-C elements allowed in the molecule
                    temperature=0.425, # Higher -> More unusual structures, more electronegatives
                    device='auto', # 'cpu', 'cuda:0' for GPUs, 'auto' to auto-determine
                    verbose=True) # Print out script preparation progress)
# Out:
# ________________________________________________________________________________________________
# [REDUCTION CANDIDATE SEARCH]
#  rc=0  cmd: /home/cameron/Documents/envs/chemflow/bin/python /home/cameron/Documents/Github/RedoxFlow/scripts/reduce.py --molecules /home/cameron/Documents/Github/RedoxFlow/memory/reactants_memory.csv --reactions /home/cameron/Documents/Github/RedoxFlow/scripts/reactions.json --out /home/cameron/Documents/Github/RedoxFlow/memory/reduction_candidates.csv --depth 2
#
# --- Output ---
# Wrote 99 rows to /home/cameron/Documents/Github/RedoxFlow/memory/reduction_candidates.csv
#
#
#
#
# ________________________________________________________________________________________________
# [CONFORMER SEARCH]
#  rc=0  cmd: /home/cameron/Documents/envs/chemflow/bin/python /home/cameron/Documents/Github/RedoxFlow/scripts/conformer.py --in /home/cameron/Documents/Github/RedoxFlow/memory/reduction_candidates.csv --out /home/cameron/Documents/Github/RedoxFlow/memory/products_memory.csv --max-confs 200 --min-steps 1000 --seed 1337 --batch-size 1000
#
# --- Output ---
# [prune] skipped (no memory): /home/cameron/Documents/Github/memory/products_memory.csv not initialized
#
#
#
# [row 0] Product_SMILES='CC(C)CNCc1ccc(F)o1' -> E=0.943780 kcal/mol
# [row 1] Product_SMILES='CC(C)CNC(=O)c1ccco1' -> E=1.723800 kcal/mol
# [row 2] Product_SMILES='C1CCOC1' -> E=0.078500 kcal/mol
# [row 3] Product_SMILES='CC(C)CNCc1ccco1' -> E=-7.682110 kcal/mol
# [row 4] Product_SMILES='CC(C)CN(Cc1ccccn1)C(C)O' -> E=0.000490 kcal/mol
# [row 5] Product_SMILES='CCN(Cc1ccccn1)CC(C)C' -> E=8.211410 kcal/mol
# [row 6] Product_SMILES='C1CCNCC1' -> E=0.759230 kcal/mol
# [row 7] Product_SMILES='Cc1noc(C)c1CNC(O)C(N)=O' -> E=4.035110 kcal/mol
# [row 8] Product_SMILES='Cc1noc(C)c1CNC(=O)C(N)O' -> E=1.202440 kcal/mol
# [row 9] Product_SMILES='Cc1noc(C)c1CNCC(N)=O' -> E=2.305250 kcal/mol
# [row 10] Product_SMILES='Cc1noc(C)c1CNC(=O)CN' -> E=0.000530 kcal/mol
# [row 11] Product_SMILES='Cc1noc(C)c1CNC(O)C(N)O' -> E=-5.382160 kcal/mol
# [row 12] Product_SMILES='Cc1noc(C)c1CNC(O)CN' -> E=-0.010400 kcal/mol
# [row 13] Product_SMILES='Cc1noc(C)c1CNCC(N)O' -> E=8.318820 kcal/mol
# [row 14] Product_SMILES='Cc1noc(C)c1CNCCN' -> E=-13.347470 kcal/mol
# [row 15] Product_SMILES='CC1CN(Cc2cnccn2)CC1C' -> E=-6.912980 kcal/mol
# [row 16] Product_SMILES='CC(C)(C)OCN1CC2CC2C1' -> E=0.213620 kcal/mol
# [row 17] Product_SMILES='CC(C)CCN1CC2CCC1CN2C' -> E=3.051030 kcal/mol
# [row 18] Product_SMILES='CC1CCN(Cc2cncnc2O)C1' -> E=-0.010590 kcal/mol
# [row 19] Product_SMILES='C1CCCCC1' -> E=-0.076060 kcal/mol
# [row 20] Product_SMILES='OCc1ccccc1' -> E=0.000000 kcal/mol
# [row 21] Product_SMILES='CC(C)C(C)NCc1ccccc1F' -> E=1.702140 kcal/mol
# [row 22] Product_SMILES='CC(C)C(C)NC(=O)c1ccccc1' -> E=0.000000 kcal/mol
# [row 23] Product_SMILES='CC(C)C(C)NCc1ccccc1' -> E=4.880140 kcal/mol
# [row 24] Product_SMILES='CCCC1CCCN1COC(C)(C)C' -> E=0.949000 kcal/mol
# [row 27] Product_SMILES='CC1CN(Cc2ccccc2)CC1C' -> E=1.789690 kcal/mol
# [row 28] Product_SMILES='CC(C)CN(CN)Cc1ccccn1' -> E=0.077920 kcal/mol
# [row 30] Product_SMILES='CNC(C)CNCc1c(C)noc1C' -> E=-7.705160 kcal/mol
# [row 31] Product_SMILES='CC(C)CC(C)NC(O)C(C)(C)C' -> E=0.001150 kcal/mol
# [row 32] Product_SMILES='CC(C)CC(C)NCC(C)(C)C' -> E=8.314460 kcal/mol
# [row 33] Product_SMILES='CC(C)C(O)N1CCCCC1C(N)=O' -> E=2.424410 kcal/mol
# [row 34] Product_SMILES='CC(C)C(=O)N1CCCCC1C(N)O' -> E=5.851470 kcal/mol
# [row 35] Product_SMILES='CC(C)CN1CCCCC1C(N)=O' -> E=2.838930 kcal/mol
# [row 36] Product_SMILES='CC(C)C(=O)N1CCCCC1CN' -> E=11.322200 kcal/mol
# [row 37] Product_SMILES='CC(C)C(O)N1CCCCC1C(N)O' -> E=1.386300 kcal/mol
# [row 38] Product_SMILES='CC(C)C(O)N1CCCCC1CN' -> E=-8.768660 kcal/mol
# [row 39] Product_SMILES='CC(C)CN1CCCCC1C(N)O' -> E=0.006420 kcal/mol
# [row 40] Product_SMILES='CC(C)CN1CCCCC1CN' -> E=28.969550 kcal/mol
# [row 41] Product_SMILES='CC(C)CCNC(O)C(N)CCCCN' -> E=-25.142840 kcal/mol
# [row 42] Product_SMILES='CC(C)CCNCC(N)CCCCN' -> E=10.611910 kcal/mol
# [row 43] Product_SMILES='CC(C)C(C)NC(O)CC1CCCCC1' -> E=3.179350 kcal/mol
# [row 44] Product_SMILES='CC(C)C(C)NCCC1CCCCC1' -> E=6.457940 kcal/mol
# [row 45] Product_SMILES='CCC(C)NC(=O)C(C)NC(O)CC' -> E=1.288650 kcal/mol
# [row 46] Product_SMILES='CCC(=O)NC(C)C(O)NC(C)CC' -> E=-11.471960 kcal/mol
# [row 47] Product_SMILES='CCCNC(C)C(=O)NC(C)CC' -> E=0.026820 kcal/mol
# [row 48] Product_SMILES='CCC(=O)NC(C)CNC(C)CC' -> E=28.093470 kcal/mol
# [row 49] Product_SMILES='CCC(C)NC(O)C(C)NC(O)CC' -> E=16.953650 kcal/mol
# [row 50] Product_SMILES='CCC(C)NCC(C)NC(O)CC' -> E=44.527920 kcal/mol
# [row 51] Product_SMILES='CCCNC(C)C(O)NC(C)CC' -> E=0.568280 kcal/mol
# [row 52] Product_SMILES='CCCNC(C)CNC(C)CC' -> E=1.184160 kcal/mol
# [row 53] Product_SMILES='CC(C)CC(=O)N1CCCCC1CO' -> E=0.047870 kcal/mol
# [row 54] Product_SMILES='CC(C)CC(O)N1CCCCC1C=O' -> E=-15.167950 kcal/mol
# [row 55] Product_SMILES='CC(C)CCN1CCCCC1C=O' -> E=0.000000 kcal/mol
# [row 56] Product_SMILES='[CH2]C1CCCCN1C(=O)CC(C)C' -> E=7.406910 kcal/mol
# [row 57] Product_SMILES='CC(C)CC(=O)N1CCCCC1C' -> E=0.000000 kcal/mol
# [row 58] Product_SMILES='CC(C)CC(O)N1CCCCC1CO' -> E=-5.960730 kcal/mol
# [row 59] Product_SMILES='CC(C)CCN1CCCCC1CO' -> E=1.459280 kcal/mol
# [row 60] Product_SMILES='[CH2]C1CCCCN1C(O)CC(C)C' -> E=4.078170 kcal/mol
# [row 61] Product_SMILES='CC(C)CC(O)N1CCCCC1C' -> E=-0.003340 kcal/mol
# [row 62] Product_SMILES='[CH2]C1CCCCN1CCC(C)C' -> E=3.900700 kcal/mol
# [row 63] Product_SMILES='CC(C)CCN1CCCCC1C' -> E=-0.604060 kcal/mol
# [row 64] Product_SMILES='COc1cc(C)ccc1NC(=O)CO' -> E=8.359530 kcal/mol
# [row 65] Product_SMILES='COc1cc(C)ccc1NC(O)C=O' -> E=-21.147750 kcal/mol
# [row 67] Product_SMILES='COc1cc(C)ccc1NCC=O' -> E=-3.957470 kcal/mol
# [row 68] Product_SMILES='[CH2]C(=O)Nc1ccc(C)cc1OC' -> E=1.886050 kcal/mol
# [row 69] Product_SMILES='COc1cc(C)ccc1NC(C)=O' -> E=5.223730 kcal/mol
# [row 70] Product_SMILES='COc1cc(C)ccc1NC(O)CO' -> E=-0.145660 kcal/mol
# [row 71] Product_SMILES='COc1cc(C)ccc1NCCO' -> E=-1.705560 kcal/mol
# [row 72] Product_SMILES='[CH2]C(O)Nc1ccc(C)cc1OC' -> E=-0.149170 kcal/mol
# [row 73] Product_SMILES='COc1cc(C)ccc1NC(C)O' -> E=7.737720 kcal/mol
# [row 74] Product_SMILES='[CH2]CNc1ccc(C)cc1OC' -> E=-27.865450 kcal/mol
# [row 75] Product_SMILES='CCNc1ccc(C)cc1OC' -> E=-15.018350 kcal/mol
# [row 76] Product_SMILES='CC(C)C(O)N1CC2CCC(C1)N2' -> E=1.083460 kcal/mol
# [row 77] Product_SMILES='CC(C)CN1CC2CCC(C1)N2' -> E=3.649770 kcal/mol
# [row 78] Product_SMILES='CC(C)CNC(O)CCc1ccccc1' -> E=0.213110 kcal/mol
# [row 80] Product_SMILES='CC(C)CNCCCc1ccccc1' -> E=2.077140 kcal/mol
# [row 81] Product_SMILES='COCC(O)N1CC2CCCC(C1)N2C' -> E=-0.731510 kcal/mol
# [row 82] Product_SMILES='COCCN1CC2CCCC(C1)N2C' -> E=9.108720 kcal/mol
# [row 83] Product_SMILES='CNCN(Cc1ccccn1)C(C)C' -> E=-15.443880 kcal/mol
# [row 85] Product_SMILES='CNc1cc(NC(O)C2CC2)ccc1C' -> E=-0.043200 kcal/mol
# [row 87] Product_SMILES='CNc1cc(NCC2CC2)ccc1C' -> E=0.960510 kcal/mol
# [row 90] Product_SMILES='CNc1ccc(N2CCCC2)cc1C' -> E=3.137450 kcal/mol
# [row 91] Product_SMILES='CC(C)C(O)N1CCCC2C1CCN2C' -> E=0.051880 kcal/mol
# [row 92] Product_SMILES='CC(C)CN1CCCC2C1CCN2C' -> E=-1.165040 kcal/mol
# [row 93] Product_SMILES='CCC(C)NC(O)CCc1ccccc1' -> E=-0.002730 kcal/mol
# [row 95] Product_SMILES='CCC(C)NCCCc1ccccc1' -> E=8.000830 kcal/mol
# [row 96] Product_SMILES='CNCC1CCCN1COC(C)(C)C' -> E=-11.276450 kcal/mol
# [row 97] Product_SMILES='CC1(C)CN(C(O)C2CC2)CCN1' -> E=-0.293560 kcal/mol
# [row 98] Product_SMILES='CC1(C)CN(CC2CC2)CCN1' -> E=1.684620 kcal/mol
# Wrote 30 winners to /home/cameron/Documents/Github/RedoxFlow/memory/products_memory.csv
# [diag] reactant '1' SMILES='CC(C)CNC(=O)c1ccc(F)o1' -> E=1.028020 kcal/mol
# [diag] reactant '2' SMILES='CC(=O)N(Cc1ccccn1)CC(C)C' -> E=2.084400 kcal/mol
# [diag] reactant '3' SMILES='Cc1noc(C)c1CNC(=O)C(N)=O' -> E=-0.033100 kcal/mol
# [diag] reactant '4' SMILES='CC1CN(C(=O)c2cnccn2)CC1C' -> E=-5.449130 kcal/mol
# [diag] reactant '5' SMILES='CC(C)(C)OC(=O)N1CC2CC2C1' -> E=-0.006150 kcal/mol
# [diag] reactant '6' SMILES='CC(C)CCN1CC2CCC1CN2C=O' -> E=8.449790 kcal/mol
# [diag] reactant '7' SMILES='CC1CCN(C(=O)c2cncnc2O)C1' -> E=-18.740940 kcal/mol
# [diag] reactant '8' SMILES='CC(C)C(C)NC(=O)c1ccccc1F' -> E=-12.667100 kcal/mol
# [diag] reactant '9' SMILES='CCCC1CCCN1C(=O)OC(C)(C)C' -> E=3.231890 kcal/mol
# [diag] reactant '10' SMILES='CC1CN(C(=O)c2ccccc2)CC1C' -> E=6.031140 kcal/mol
# [diag] reactant '11' SMILES='CC(C)CN(Cc1ccccn1)C(N)=O' -> E=0.897130 kcal/mol
# [diag] reactant '12' SMILES='Cc1noc(C)c1CNCC(C)NC=O' -> E=-1.195180 kcal/mol
# [diag] reactant '13' SMILES='CC(C)CC(C)NC(=O)C(C)(C)C' -> E=-0.000910 kcal/mol
# [diag] reactant '14' SMILES='CC(C)C(=O)N1CCCCC1C(N)=O' -> E=27.655450 kcal/mol
# [diag] reactant '15' SMILES='CC(C)CCNC(=O)C(N)CCCCN' -> E=-12.498180 kcal/mol
# [diag] reactant '16' SMILES='CC(C)C(C)NC(=O)CC1CCCCC1' -> E=24.121330 kcal/mol
# [diag] reactant '17' SMILES='CCC(=O)NC(C)C(=O)NC(C)CC' -> E=1.176320 kcal/mol
# [diag] reactant '18' SMILES='CC(C)CC(=O)N1CCCCC1C=O' -> E=3.521130 kcal/mol
# [diag] reactant '19' SMILES='COc1cc(C)ccc1NC(=O)C=O' -> E=0.185630 kcal/mol
# [diag] reactant '20' SMILES='CC(C)C(=O)N1CC2CCC(C1)N2' -> E=-0.502190 kcal/mol
# [diag] reactant '21' SMILES='CC(C)CNC(=O)CCc1ccccc1' -> E=0.003160 kcal/mol
# [diag] reactant '22' SMILES='COCC(=O)N1CC2CCCC(C1)N2C' -> E=6.993940 kcal/mol
# [diag] reactant '23' SMILES='CNC(=O)N(Cc1ccccn1)C(C)C' -> E=-13.524360 kcal/mol
# [diag] reactant '24' SMILES='CNc1cc(NC(=O)C2CC2)ccc1C' -> E=-2.146380 kcal/mol
# [diag] reactant '25' SMILES='Cc1nn(-c2ccccc2)c(C)c1CN' -> E=2.500140 kcal/mol
# [diag] reactant '26' SMILES='Cc1cc(N2CCCC2)ccc1NC=O' -> E=11.356440 kcal/mol
# [diag] reactant '27' SMILES='CC(C)C(=O)N1CCCC2C1CCN2C' -> E=1.031110 kcal/mol
# [diag] reactant '28' SMILES='CCC(C)NC(=O)CCc1ccccc1' -> E=3.066740 kcal/mol
# [diag] reactant '29' SMILES='CNCC1CCCN1C(=O)OC(C)(C)C' -> E=0.005770 kcal/mol
# [diag] reactant '30' SMILES='CC1(C)CN(C(=O)C2CC2)CCN1' -> E=26.862730 kcal/mol
#
# ________________________________________________________________________________________________
# [SCRIPT GENERATION]
#  rc=0  cmd: /home/cameron/Documents/envs/chemflow/bin/python /home/cameron/Documents/Github/RedoxFlow/scripts/generate_nw.py --reactants_in /home/cameron/Documents/Github/RedoxFlow/memory/reactants --products_in /home/cameron/Documents/Github/RedoxFlow/memory/products --scripts_out /home/cameron/Documents/Github/RedoxFlow/memory/scripts
#
# --- Output ---
# [info] found 60 XYZ files in /home/cameron/Documents/Github/RedoxFlow/memory/reactants, /home/cameron/Documents/Github/RedoxFlow/memory/products
# [do ] reactant  react_1.xyz                SMILES=CC(C)CNC(=O)c1ccc(F)o1
# [ok] wrote /home/cameron/Documents/Github/RedoxFlow/memory/scripts/reactants/react_1/react_1.nw  (geom=react_1.xyz, charge=0, mult=1)
# [do ] reactant  react_10.xyz               SMILES=CC1CN(C(=O)c2ccccc2)CC1C
# [ok] wrote /home/cameron/Documents/Github/RedoxFlow/memory/scripts/reactants/react_10/react_10.nw  (geom=react_10.xyz, charge=0, mult=1)
# [do ] reactant  react_11.xyz               SMILES=CC(C)CN(Cc1ccccn1)C(N)=O
# [ok] wrote /home/cameron/Documents/Github/RedoxFlow/memory/scripts/reactants/react_11/react_11.nw  (geom=react_11.xyz, charge=0, mult=1)
# [do ] reactant  react_12.xyz               SMILES=Cc1noc(C)c1CNCC(C)NC=O
# [ok] wrote /home/cameron/Documents/Github/RedoxFlow/memory/scripts/reactants/react_12/react_12.nw  (geom=react_12.xyz, charge=0, mult=1)
# [do ] reactant  react_13.xyz               SMILES=CC(C)CC(C)NC(=O)C(C)(C)C
# [ok] wrote /home/cameron/Documents/Github/RedoxFlow/memory/scripts/reactants/react_13/react_13.nw  (geom=react_13.xyz, charge=0, mult=1)
# [do ] reactant  react_14.xyz               SMILES=CC(C)C(=O)N1CCCCC1C(N)=O
# [ok] wrote /home/cameron/Documents/Github/RedoxFlow/memory/scripts/reactants/react_14/react_14.nw  (geom=react_14.xyz, charge=0, mult=1)
# [do ] reactant  react_15.xyz               SMILES=CC(C)CCNC(=O)C(N)CCCCN
# [ok] wrote /home/cameron/Documents/Github/RedoxFlow/memory/scripts/reactants/react_15/react_15.nw  (geom=react_15.xyz, charge=0, mult=1)
# [do ] reactant  react_16.xyz               SMILES=CC(C)C(C)NC(=O)CC1CCCCC1
# [ok] wrote /home/cameron/Documents/Github/RedoxFlow/memory/scripts/reactants/react_16/react_16.nw  (geom=react_16.xyz, charge=0, mult=1)
# [do ] reactant  react_17.xyz               SMILES=CCC(=O)NC(C)C(=O)NC(C)CC
# [ok] wrote /home/cameron/Documents/Github/RedoxFlow/memory/scripts/reactants/react_17/react_17.nw  (geom=react_17.xyz, charge=0, mult=1)
# [do ] reactant  react_18.xyz               SMILES=CC(C)CC(=O)N1CCCCC1C=O
# [ok] wrote /home/cameron/Documents/Github/RedoxFlow/memory/scripts/reactants/react_18/react_18.nw  (geom=react_18.xyz, charge=0, mult=1)
# [do ] reactant  react_19.xyz               SMILES=COc1cc(C)ccc1NC(=O)C=O
# [ok] wrote /home/cameron/Documents/Github/RedoxFlow/memory/scripts/reactants/react_19/react_19.nw  (geom=react_19.xyz, charge=0, mult=1)
# [do ] reactant  react_2.xyz                SMILES=CC(=O)N(Cc1ccccn1)CC(C)C
# [ok] wrote /home/cameron/Documents/Github/RedoxFlow/memory/scripts/reactants/react_2/react_2.nw  (geom=react_2.xyz, charge=0, mult=1)
# [do ] reactant  react_20.xyz               SMILES=CC(C)C(=O)N1CC2CCC(C1)N2
# [ok] wrote /home/cameron/Documents/Github/RedoxFlow/memory/scripts/reactants/react_20/react_20.nw  (geom=react_20.xyz, charge=0, mult=1)
# [do ] reactant  react_21.xyz               SMILES=CC(C)CNC(=O)CCc1ccccc1
# [ok] wrote /home/cameron/Documents/Github/RedoxFlow/memory/scripts/reactants/react_21/react_21.nw  (geom=react_21.xyz, charge=0, mult=1)
# [do ] reactant  react_22.xyz               SMILES=COCC(=O)N1CC2CCCC(C1)N2C
# [ok] wrote /home/cameron/Documents/Github/RedoxFlow/memory/scripts/reactants/react_22/react_22.nw  (geom=react_22.xyz, charge=0, mult=1)
# [do ] reactant  react_23.xyz               SMILES=CNC(=O)N(Cc1ccccn1)C(C)C
# [ok] wrote /home/cameron/Documents/Github/RedoxFlow/memory/scripts/reactants/react_23/react_23.nw  (geom=react_23.xyz, charge=0, mult=1)
# [do ] reactant  react_24.xyz               SMILES=CNc1cc(NC(=O)C2CC2)ccc1C
# [ok] wrote /home/cameron/Documents/Github/RedoxFlow/memory/scripts/reactants/react_24/react_24.nw  (geom=react_24.xyz, charge=0, mult=1)
# [do ] reactant  react_25.xyz               SMILES=Cc1nn(-c2ccccc2)c(C)c1CN
# [ok] wrote /home/cameron/Documents/Github/RedoxFlow/memory/scripts/reactants/react_25/react_25.nw  (geom=react_25.xyz, charge=0, mult=1)
# [do ] reactant  react_26.xyz               SMILES=Cc1cc(N2CCCC2)ccc1NC=O
# [ok] wrote /home/cameron/Documents/Github/RedoxFlow/memory/scripts/reactants/react_26/react_26.nw  (geom=react_26.xyz, charge=0, mult=1)
# [do ] reactant  react_27.xyz               SMILES=CC(C)C(=O)N1CCCC2C1CCN2C
# [ok] wrote /home/cameron/Documents/Github/RedoxFlow/memory/scripts/reactants/react_27/react_27.nw  (geom=react_27.xyz, charge=0, mult=1)
# [do ] reactant  react_28.xyz               SMILES=CCC(C)NC(=O)CCc1ccccc1
# [ok] wrote /home/cameron/Documents/Github/RedoxFlow/memory/scripts/reactants/react_28/react_28.nw  (geom=react_28.xyz, charge=0, mult=1)
# [do ] reactant  react_29.xyz               SMILES=CNCC1CCCN1C(=O)OC(C)(C)C
# [ok] wrote /home/cameron/Documents/Github/RedoxFlow/memory/scripts/reactants/react_29/react_29.nw  (geom=react_29.xyz, charge=0, mult=1)
# [do ] reactant  react_3.xyz                SMILES=Cc1noc(C)c1CNC(=O)C(N)=O
# [ok] wrote /home/cameron/Documents/Github/RedoxFlow/memory/scripts/reactants/react_3/react_3.nw  (geom=react_3.xyz, charge=0, mult=1)
# [do ] reactant  react_30.xyz               SMILES=CC1(C)CN(C(=O)C2CC2)CCN1
# [ok] wrote /home/cameron/Documents/Github/RedoxFlow/memory/scripts/reactants/react_30/react_30.nw  (geom=react_30.xyz, charge=0, mult=1)
# [do ] reactant  react_4.xyz                SMILES=CC1CN(C(=O)c2cnccn2)CC1C
# [ok] wrote /home/cameron/Documents/Github/RedoxFlow/memory/scripts/reactants/react_4/react_4.nw  (geom=react_4.xyz, charge=0, mult=1)
# [do ] reactant  react_5.xyz                SMILES=CC(C)(C)OC(=O)N1CC2CC2C1
# [ok] wrote /home/cameron/Documents/Github/RedoxFlow/memory/scripts/reactants/react_5/react_5.nw  (geom=react_5.xyz, charge=0, mult=1)
# [do ] reactant  react_6.xyz                SMILES=CC(C)CCN1CC2CCC1CN2C=O
# [ok] wrote /home/cameron/Documents/Github/RedoxFlow/memory/scripts/reactants/react_6/react_6.nw  (geom=react_6.xyz, charge=0, mult=1)
# [do ] reactant  react_7.xyz                SMILES=CC1CCN(C(=O)c2cncnc2O)C1
# [ok] wrote /home/cameron/Documents/Github/RedoxFlow/memory/scripts/reactants/react_7/react_7.nw  (geom=react_7.xyz, charge=0, mult=1)
# [do ] reactant  react_8.xyz                SMILES=CC(C)C(C)NC(=O)c1ccccc1F
# [ok] wrote /home/cameron/Documents/Github/RedoxFlow/memory/scripts/reactants/react_8/react_8.nw  (geom=react_8.xyz, charge=0, mult=1)
# [do ] reactant  react_9.xyz                SMILES=CCCC1CCCN1C(=O)OC(C)(C)C
# [ok] wrote /home/cameron/Documents/Github/RedoxFlow/memory/scripts/reactants/react_9/react_9.nw  (geom=react_9.xyz, charge=0, mult=1)
# [do ] product   prod_1.xyz                 SMILES=CC(C)CNCc1ccco1
# [ok] wrote /home/cameron/Documents/Github/RedoxFlow/memory/scripts/products/prod_1/prod_1.nw  (geom=prod_1.xyz, charge=0, mult=1)
# [do ] product   prod_10.xyz                SMILES=C1CCCCC1
# [ok] wrote /home/cameron/Documents/Github/RedoxFlow/memory/scripts/products/prod_10/prod_10.nw  (geom=prod_10.xyz, charge=0, mult=1)
# [do ] product   prod_11.xyz                SMILES=CC(C)CN(CN)Cc1ccccn1
# [ok] wrote /home/cameron/Documents/Github/RedoxFlow/memory/scripts/products/prod_11/prod_11.nw  (geom=prod_11.xyz, charge=0, mult=1)
# [do ] product   prod_12.xyz                SMILES=CNC(C)CNCc1c(C)noc1C
# [ok] wrote /home/cameron/Documents/Github/RedoxFlow/memory/scripts/products/prod_12/prod_12.nw  (geom=prod_12.xyz, charge=0, mult=1)
# [do ] product   prod_13.xyz                SMILES=CC(C)CC(C)NC(O)C(C)(C)C
# [ok] wrote /home/cameron/Documents/Github/RedoxFlow/memory/scripts/products/prod_13/prod_13.nw  (geom=prod_13.xyz, charge=0, mult=1)
# [do ] product   prod_14.xyz                SMILES=CC(C)C(O)N1CCCCC1CN
# [ok] wrote /home/cameron/Documents/Github/RedoxFlow/memory/scripts/products/prod_14/prod_14.nw  (geom=prod_14.xyz, charge=0, mult=1)
# [do ] product   prod_15.xyz                SMILES=CC(C)CCNC(O)C(N)CCCCN
# [ok] wrote /home/cameron/Documents/Github/RedoxFlow/memory/scripts/products/prod_15/prod_15.nw  (geom=prod_15.xyz, charge=0, mult=1)
# [do ] product   prod_16.xyz                SMILES=CC(C)C(C)NC(O)CC1CCCCC1
# [ok] wrote /home/cameron/Documents/Github/RedoxFlow/memory/scripts/products/prod_16/prod_16.nw  (geom=prod_16.xyz, charge=0, mult=1)
# [do ] product   prod_17.xyz                SMILES=CCC(=O)NC(C)C(O)NC(C)CC
# [ok] wrote /home/cameron/Documents/Github/RedoxFlow/memory/scripts/products/prod_17/prod_17.nw  (geom=prod_17.xyz, charge=0, mult=1)
# [do ] product   prod_18.xyz                SMILES=CC(C)CC(O)N1CCCCC1C=O
# [ok] wrote /home/cameron/Documents/Github/RedoxFlow/memory/scripts/products/prod_18/prod_18.nw  (geom=prod_18.xyz, charge=0, mult=1)
# [do ] product   prod_19.xyz                SMILES=[CH2]CNc1ccc(C)cc1OC
# [ok] wrote /home/cameron/Documents/Github/RedoxFlow/memory/scripts/products/prod_19/prod_19.nw  (geom=prod_19.xyz, charge=0, mult=2)
# [do ] product   prod_2.xyz                 SMILES=CC(C)CN(Cc1ccccn1)C(C)O
# [ok] wrote /home/cameron/Documents/Github/RedoxFlow/memory/scripts/products/prod_2/prod_2.nw  (geom=prod_2.xyz, charge=0, mult=1)
# [do ] product   prod_20.xyz                SMILES=CC(C)C(O)N1CC2CCC(C1)N2
# [ok] wrote /home/cameron/Documents/Github/RedoxFlow/memory/scripts/products/prod_20/prod_20.nw  (geom=prod_20.xyz, charge=0, mult=1)
# [do ] product   prod_21.xyz                SMILES=C1CCCCC1
# [ok] wrote /home/cameron/Documents/Github/RedoxFlow/memory/scripts/products/prod_21/prod_21.nw  (geom=prod_21.xyz, charge=0, mult=1)
# [do ] product   prod_22.xyz                SMILES=COCC(O)N1CC2CCCC(C1)N2C
# [ok] wrote /home/cameron/Documents/Github/RedoxFlow/memory/scripts/products/prod_22/prod_22.nw  (geom=prod_22.xyz, charge=0, mult=1)
# [do ] product   prod_23.xyz                SMILES=CNCN(Cc1ccccn1)C(C)C
# [ok] wrote /home/cameron/Documents/Github/RedoxFlow/memory/scripts/products/prod_23/prod_23.nw  (geom=prod_23.xyz, charge=0, mult=1)
# [do ] product   prod_24.xyz                SMILES=C1CCCCC1
# [ok] wrote /home/cameron/Documents/Github/RedoxFlow/memory/scripts/products/prod_24/prod_24.nw  (geom=prod_24.xyz, charge=0, mult=1)
# [do ] product   prod_25.xyz                SMILES=C1CCCCC1
# [ok] wrote /home/cameron/Documents/Github/RedoxFlow/memory/scripts/products/prod_25/prod_25.nw  (geom=prod_25.xyz, charge=0, mult=1)
# [do ] product   prod_26.xyz                SMILES=C1CCCCC1
# [ok] wrote /home/cameron/Documents/Github/RedoxFlow/memory/scripts/products/prod_26/prod_26.nw  (geom=prod_26.xyz, charge=0, mult=1)
# [do ] product   prod_27.xyz                SMILES=CC(C)CN1CCCC2C1CCN2C
# [ok] wrote /home/cameron/Documents/Github/RedoxFlow/memory/scripts/products/prod_27/prod_27.nw  (geom=prod_27.xyz, charge=0, mult=1)
# [do ] product   prod_28.xyz                SMILES=C1CCCCC1
# [ok] wrote /home/cameron/Documents/Github/RedoxFlow/memory/scripts/products/prod_28/prod_28.nw  (geom=prod_28.xyz, charge=0, mult=1)
# [do ] product   prod_29.xyz                SMILES=CNCC1CCCN1COC(C)(C)C
# [ok] wrote /home/cameron/Documents/Github/RedoxFlow/memory/scripts/products/prod_29/prod_29.nw  (geom=prod_29.xyz, charge=0, mult=1)
# [do ] product   prod_3.xyz                 SMILES=Cc1noc(C)c1CNCCN
# [ok] wrote /home/cameron/Documents/Github/RedoxFlow/memory/scripts/products/prod_3/prod_3.nw  (geom=prod_3.xyz, charge=0, mult=1)
# [do ] product   prod_30.xyz                SMILES=CC1(C)CN(C(O)C2CC2)CCN1
# [ok] wrote /home/cameron/Documents/Github/RedoxFlow/memory/scripts/products/prod_30/prod_30.nw  (geom=prod_30.xyz, charge=0, mult=1)
# [do ] product   prod_4.xyz                 SMILES=CC1CN(Cc2cnccn2)CC1C
# [ok] wrote /home/cameron/Documents/Github/RedoxFlow/memory/scripts/products/prod_4/prod_4.nw  (geom=prod_4.xyz, charge=0, mult=1)
# [do ] product   prod_5.xyz                 SMILES=CC(C)(C)OCN1CC2CC2C1
# [ok] wrote /home/cameron/Documents/Github/RedoxFlow/memory/scripts/products/prod_5/prod_5.nw  (geom=prod_5.xyz, charge=0, mult=1)
# [do ] product   prod_6.xyz                 SMILES=CC(C)CCN1CC2CCC1CN2C
# [ok] wrote /home/cameron/Documents/Github/RedoxFlow/memory/scripts/products/prod_6/prod_6.nw  (geom=prod_6.xyz, charge=0, mult=1)
# [do ] product   prod_7.xyz                 SMILES=CC1CCN(Cc2cncnc2O)C1
# [ok] wrote /home/cameron/Documents/Github/RedoxFlow/memory/scripts/products/prod_7/prod_7.nw  (geom=prod_7.xyz, charge=0, mult=1)
# [do ] product   prod_8.xyz                 SMILES=C1CCCCC1
# [ok] wrote /home/cameron/Documents/Github/RedoxFlow/memory/scripts/products/prod_8/prod_8.nw  (geom=prod_8.xyz, charge=0, mult=1)
# [do ] product   prod_9.xyz                 SMILES=CCCC1CCCN1COC(C)(C)C
# [ok] wrote /home/cameron/Documents/Github/RedoxFlow/memory/scripts/products/prod_9/prod_9.nw  (geom=prod_9.xyz, charge=0, mult=1)
# [done] 60 ok, 0 failed
#
#
#
#
# ________________________________________________________________________________________________
